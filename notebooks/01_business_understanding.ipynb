# %% [markdown]
# # Spotify Popularity Prediction

# %% [markdown]
# ## 1. Business Understanding

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# ### Business Objectives

# %% [markdown]
# ### Project Objectives

# %% [markdown]
# ### Success Criteria

# %% [markdown]
# ### Initial Assessment
